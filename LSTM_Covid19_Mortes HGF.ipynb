# %% [markdown]
# LSTM óbitos de Covid

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import tensorflow as tf
from datetime import datetime

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM, GRU, CuDNNLSTM, CuDNNGRU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

import warnings
|#warnings.filterwarnings('ignore')
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (c:\Users\hgf77\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:301180)
# at w.execute (c:\Users\hgf77\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:300551)
# at w.start (c:\Users\hgf77\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:296215)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at t.CellExecutionQueue.executeQueuedCells (c:\Users\hgf77\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:310950)
# at t.CellExecutionQueue.start (c:\Users\hgf77\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:310490)

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
#print(tf.config.experimental.list_physical_devices())
# Out:
# Num GPUs Available:  1

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i+look_back, 0])
	return np.array(dataX), np.array(dataY)

def plot_history(history):
    mse = history.history['loss']
    val_mse = history.history['val_loss']
    x = range(1, len(mse) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, mse, 'b', label='Training MSE')
    plt.plot(x, val_mse, 'r', label='Validation MSE')
    plt.title('Training and validation LOSS - MSE')
    plt.xlabel('epoca')
    plt.ylabel('mse')
    plt.legend()
    
def predict_until_new_year(dataset, look_back=1):
    predictArr = []
    predictArr = np.array([], dtype=np.float64)
    predictArr = predictArr.astype('float32').reshape(-1,1)
    X = np.array(dataset.newDeaths)
    X = X.astype('float32').reshape(-1,1)
    ano_novo = datetime.strptime('2021-12-31', '%Y-%m-%d')
    hoje = datetime.today()
    dias_ate_ano_novo = abs((ano_novo - hoje).days)
    print(f"dias até o ano novo {dias_ate_ano_novo}")
    for i in range(dias_ate_ano_novo, 0, -1):
        print(f"prevendo taxa de óbitos para o dia {i} até o ano novo")
        data_para_previsao = scaler.fit_transform(X[look_back*-1:])
        data_para_previsao = np.reshape(data_para_previsao, (1, data_para_previsao.shape[0], 1))
        predict = model.predict(data_para_previsao)
        invpredict = scaler.inverse_transform(predict)
        X = np.append(X, invpredict, axis=0)
        predictArr = np.append(predictArr, invpredict, axis=0)
    return predictArr

def predict_for_next_year(dataset, look_back=1):
    predictArr = []
    predictArr = np.array([], dtype=np.float64)
    predictArr = predictArr.astype('float32').reshape(-1,1)
    X = np.array(dataset.newDeaths)
    X = X.astype('float32').reshape(-1,1)
    print(f"Prevendo óbitos para o próximo ano!!")
    for i in range(1, 365, 1):
        print(f"prevendo taxa de óbitos para o dia {i} do próximo ano")
        data_para_previsao = scaler.fit_transform(X[look_back*-1:])
        data_para_previsao = np.reshape(data_para_previsao, (1, data_para_previsao.shape[0], 1))
        predict = model.predict(data_para_previsao)
        invpredict = scaler.inverse_transform(predict)
        X = np.append(X, invpredict, axis=0)
        predictArr = np.append(predictArr, invpredict, axis=0)
    return predictArr

# %%
df = pd.read_csv("https://raw.githubusercontent.com/wcota/covid19br/master/cases-brazil-states.csv")

# %%
# change date column to datetime format
df['date'] = pd.to_datetime(df['date'])

# print all available columns
print(df.columns)

# filter data for Brazil, and show only the specified columns
data_BR = df.query("state == 'TOTAL'")[['date', 'newDeaths']]

# display the dataframe
data_BR
# Out:
# Index(['epi_week', 'date', 'country', 'state', 'city', 'newDeaths', 'deaths',
#        'newCases', 'totalCases', 'deathsMS', 'totalCasesMS',
#        'deaths_per_100k_inhabitants', 'totalCases_per_100k_inhabitants',
#        'deaths_by_totalCases', 'recovered', 'suspects', 'tests',
#        'tests_per_100k_inhabitants', 'vaccinated',
#        'vaccinated_per_100_inhabitants', 'vaccinated_second',
#        'vaccinated_second_per_100_inhabitants', 'vaccinated_single',
#        'vaccinated_single_per_100_inhabitants', 'vaccinated_third',
#        'vaccinated_third_per_100_inhabitants'],
#       dtype='object')
#             date  newDeaths
# 1     2020-02-25          0
# 3     2020-02-26          0
# 5     2020-02-27          0
# 7     2020-02-28          0
# 9     2020-02-29          0
# ...          ...        ...
# 16505 2021-10-22        447
# 16533 2021-10-23        350
# 16561 2021-10-24        119
# 16589 2021-10-25        207
# 16617 2021-10-26        391
#
# [610 rows x 2 columns]

# %%
fig = plt.figure(figsize=(20,8))
sns.scatterplot(x=df.date, y=df.newDeaths)
plt.title('Mortes por dia', size=24)
plt.show()

# %%
sns.histplot(data_BR.newDeaths)
# Out:
# <AxesSubplot:xlabel='newDeaths', ylabel='Count'>

# %% [markdown]
# # Previsão

# %%
X = np.array(data_BR.newDeaths)
X = X.astype('float32').reshape(-1,1)

# %%
scaler = MinMaxScaler()
#scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
train_size = int(len(X) * 0.7)
test_size = len(X) - train_size

train = X[0:train_size,:]
test =  X[train_size:len(X),:]

# %%
plt.plot(train)

# %%
best = 0
best_mse = np.Infinity
for n in range(1, 21, 1):
    look_back = n
    X_train, y_train = create_dataset(train, look_back)
    X_test, y_test = create_dataset(test, look_back)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    model = Sequential()
    #model.add(LSTM(128, input_shape=(look_back, 1),return_sequences=True, dropout=0.2))
    #model.add(LSTM(64, input_shape=(128, 1), dropout=0.2))
    model.add(CuDNNLSTM(128, input_shape=(len(X_train), len(X_train[0])),return_sequences=True))
    model.add(Dropout(0.2))
    model.add(Dense(32))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=1, verbose=0)
    mse = min(history.history['val_loss'])
    if best_mse > mse:
        best_mse = mse
        best = n
    print(f"look back {n} - {mse} | best {best} - {best_mse}")
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 608, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 608, 1), dtype=tf.float32, name='cu_dnnlstm_input'), name='cu_dnnlstm_input', description="created by layer 'cu_dnnlstm_input'"), but it was called on an input with incompatible shape (1, 1, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 608, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 608, 1), dtype=tf.float32, name='cu_dnnlstm_input'), name='cu_dnnlstm_input', description="created by layer 'cu_dnnlstm_input'"), but it was called on an input with incompatible shape (1, 1, 1).

# %%
# quantidade de atrasos
look_back = 17

X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
X_train.shape
# Out:
# (409, 17, 1)

# %%
model = Sequential()
#model.add(LSTM(128, input_shape=(look_back, 1),return_sequences=True, dropout=0.2))
#model.add(LSTM(64, input_shape=(128, 1), dropout=0.2))
model.add(CuDNNLSTM(128,input_shape=(look_back, 1), return_sequences=True))
model.add(CuDNNLSTM(64,return_sequences=True))
model.add(Dense(32))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cu_dnnlstm_3 (CuDNNLSTM)     (None, 17, 128)           67072
# _________________________________________________________________
# cu_dnnlstm_4 (CuDNNLSTM)     (None, 17, 64)            49664
# _________________________________________________________________
# dense_4 (Dense)              (None, 17, 32)            2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 17, 32)            0
# _________________________________________________________________
# dense_5 (Dense)              (None, 17, 1)             33
# =================================================================
# Total params: 118,849
# Trainable params: 118,849
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath='./modelo_lstm_covid_mortes.hdf5', verbose=1, save_best_only=True, monitor='val_loss')

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=1, callbacks=[checkpointer])
# Out:
# Epoch 1/100

# %%
plot_history(history)

# %%
model = load_model("./modelo_lstm_covid_mortes.hdf5")
# Predições
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# %%
# Faz a transformação inversa das predições
trainPredict = scaler.inverse_transform(trainPredict)
y_tr = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_te = scaler.inverse_transform([y_test])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(y_tr[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_te[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 304.61 RMSE
# Test Score: 218.42 RMSE

# %%
# Prepara o vetor para plotagem do conjunto de treinamento
trainPredictPlot = np.empty_like(X)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back-1:len(trainPredict)+look_back-1, :] = trainPredict

# Prepara o vetor para plotagem do conjunto das predições
testPredictPlot = np.empty_like(X)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(X)-len(testPredict):len(X), :] = testPredict

# Plota o dataset, as predições sobre o conjunto de treinamento e teste
plt.figure(figsize=(20,14))
plt.plot(scaler.inverse_transform(X), color='b')
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
previsoes_final_ano = predict_until_new_year(data_BR, look_back)
# Out:
# dias até o ano novo 73
# prevendo taxa de óbitos para o dia 73 até o ano novo
# prevendo taxa de óbitos para o dia 72 até o ano novo
# prevendo taxa de óbitos para o dia 71 até o ano novo
# prevendo taxa de óbitos para o dia 70 até o ano novo
# prevendo taxa de óbitos para o dia 69 até o ano novo
# prevendo taxa de óbitos para o dia 68 até o ano novo
# prevendo taxa de óbitos para o dia 67 até o ano novo
# prevendo taxa de óbitos para o dia 66 até o ano novo
# prevendo taxa de óbitos para o dia 65 até o ano novo
# prevendo taxa de óbitos para o dia 64 até o ano novo
# prevendo taxa de óbitos para o dia 63 até o ano novo
# prevendo taxa de óbitos para o dia 62 até o ano novo
# prevendo taxa de óbitos para o dia 61 até o ano novo
# prevendo taxa de óbitos para o dia 60 até o ano novo
# prevendo taxa de óbitos para o dia 59 até o ano novo
# prevendo taxa de óbitos para o dia 58 até o ano novo
# prevendo taxa de óbitos para o dia 57 até o ano novo
# prevendo taxa de óbitos para o dia 56 até o ano novo
# prevendo taxa de óbitos para o dia 55 até o ano novo
# prevendo taxa de óbitos para o dia 54 até o ano novo
# prevendo taxa de óbitos para o dia 53 até o ano novo
# prevendo taxa de óbitos para o dia 52 até o ano novo
# prevendo taxa de óbitos para o dia 51 até o ano novo
# prevendo taxa de óbitos para o dia 50 até o ano novo
# prevendo taxa de óbitos para o dia 49 até o ano novo
# prevendo taxa de óbitos para o dia 48 até o ano novo
# prevendo taxa de óbitos para o dia 47 até o ano novo
# prevendo taxa de óbitos para o dia 46 até o ano novo
# prevendo taxa de óbitos para o dia 45 até o ano novo
# prevendo taxa de óbitos para o dia 44 até o ano novo
# prevendo taxa de óbitos para o dia 43 até o ano novo
# prevendo taxa de óbitos para o dia 42 até o ano novo
# prevendo taxa de óbitos para o dia 41 até o ano novo
# prevendo taxa de óbitos para o dia 40 até o ano novo
# prevendo taxa de óbitos para o dia 39 até o ano novo
# prevendo taxa de óbitos para o dia 38 até o ano novo
# prevendo taxa de óbitos para o dia 37 até o ano novo
# prevendo taxa de óbitos para o dia 36 até o ano novo
# prevendo taxa de óbitos para o dia 35 até o ano novo
# prevendo taxa de óbitos para o dia 34 até o ano novo
# prevendo taxa de óbitos para o dia 33 até o ano novo
# prevendo taxa de óbitos para o dia 32 até o ano novo
# prevendo taxa de óbitos para o dia 31 até o ano novo
# prevendo taxa de óbitos para o dia 30 até o ano novo
# prevendo taxa de óbitos para o dia 29 até o ano novo
# prevendo taxa de óbitos para o dia 28 até o ano novo
# prevendo taxa de óbitos para o dia 27 até o ano novo
# prevendo taxa de óbitos para o dia 26 até o ano novo
# prevendo taxa de óbitos para o dia 25 até o ano novo
# prevendo taxa de óbitos para o dia 24 até o ano novo
# prevendo taxa de óbitos para o dia 23 até o ano novo
# prevendo taxa de óbitos para o dia 22 até o ano novo
# prevendo taxa de óbitos para o dia 21 até o ano novo
# prevendo taxa de óbitos para o dia 20 até o ano novo
# prevendo taxa de óbitos para o dia 19 até o ano novo
# prevendo taxa de óbitos para o dia 18 até o ano novo
# prevendo taxa de óbitos para o dia 17 até o ano novo
# prevendo taxa de óbitos para o dia 16 até o ano novo
# prevendo taxa de óbitos para o dia 15 até o ano novo
# prevendo taxa de óbitos para o dia 14 até o ano novo
# prevendo taxa de óbitos para o dia 13 até o ano novo
# prevendo taxa de óbitos para o dia 12 até o ano novo
# prevendo taxa de óbitos para o dia 11 até o ano novo
# prevendo taxa de óbitos para o dia 10 até o ano novo
# prevendo taxa de óbitos para o dia 9 até o ano novo
# prevendo taxa de óbitos para o dia 8 até o ano novo
# prevendo taxa de óbitos para o dia 7 até o ano novo
# prevendo taxa de óbitos para o dia 6 até o ano novo
# prevendo taxa de óbitos para o dia 5 até o ano novo
# prevendo taxa de óbitos para o dia 4 até o ano novo
# prevendo taxa de óbitos para o dia 3 até o ano novo
# prevendo taxa de óbitos para o dia 2 até o ano novo
# prevendo taxa de óbitos para o dia 1 até o ano novo

# %%
X = np.array(data_BR.newDeaths)
X = X.astype('float32').reshape(-1,1)

# Prepara o vetor para plotagem dos valores originais
originalX = np.empty([len(X)+len(previsoes_final_ano), ]).reshape(-1,1)
originalX[:, :] = np.nan
originalX[0:len(X), :] = X

# Prepara o vetor para plotagem do conjunto das predições
PredictPlot = np.empty_like(originalX)
PredictPlot[:, :] = np.nan
PredictPlot[len(X):len(X)+len(previsoes_final_ano), :] = previsoes_final_ano

# Plota o dataset, as predições sobre o conjunto de treinamento e teste
plt.figure(figsize=(20,14))
plt.plot(originalX, color = 'b')
plt.plot(PredictPlot, color='r')
plt.show()

# %%
previsoes_final_ano
# Out:
# array([[302.3142 ],
#        [267.8532 ],
#        [335.1274 ],
#        [309.6184 ],
#        [277.33228],
#        [232.3173 ],
#        [192.62733],
#        [186.82039],
#        [237.1979 ],
#        [237.05797],
#        [232.75325],
#        [211.88011],
#        [180.06807],
#        [144.3968 ],
#        [163.08127],
#        [186.96054],
#        [192.52382],
#        [188.22598],
#        [181.1005 ],
#        [169.2771 ],
#        [152.37662],
#        [152.44746],
#        [173.68617],
#        [170.20386],
#        [166.99776],
#        [162.97055],
#        [156.76836],
#        [147.59761],
#        [153.02693],
#        [163.80405],
#        [159.85085],
#        [158.4697 ],
#        [156.0855 ],
#        [152.62605],
#        [147.97499],
#        [152.6883 ],
#        [157.34761],
#        [155.61797],
#        [154.63028],
#        [152.8073 ],
#        [150.76155],
#        [148.52818],
#        [151.1693 ],
#        [153.91542],
#        [152.49753],
#        [151.77919],
#        [150.80458],
#        [149.69125],
#        [148.81662],
#        [150.25386],
#        [151.55937],
#        [150.69449],
#        [150.41264],
#        [149.86047],
#        [149.14983],
#        [148.79979],
#        [149.80547],
#        [150.24635],
#        [149.85495],
#        [149.7521 ],
#        [149.44383],
#        [149.03342],
#        [148.9678 ],
#        [149.5077 ],
#        [149.62651],
#        [149.45032],
#        [149.31679],
#        [149.13316],
#        [148.9062 ],
#        [149.00986],
#        [149.31956],
#        [149.2864 ],
#        [149.1959 ]], dtype=float32)

# %%
previsoes_proximo_ano = predict_for_next_year(data_BR, look_back)
# Out:
# Prevendo óbitos para o próximo ano!!
# prevendo taxa de óbitos para o dia 1 até o ano novo
# prevendo taxa de óbitos para o dia 2 até o ano novo
# prevendo taxa de óbitos para o dia 3 até o ano novo
# prevendo taxa de óbitos para o dia 4 até o ano novo
# prevendo taxa de óbitos para o dia 5 até o ano novo
# prevendo taxa de óbitos para o dia 6 até o ano novo
# prevendo taxa de óbitos para o dia 7 até o ano novo
# prevendo taxa de óbitos para o dia 8 até o ano novo
# prevendo taxa de óbitos para o dia 9 até o ano novo
# prevendo taxa de óbitos para o dia 10 até o ano novo
# prevendo taxa de óbitos para o dia 11 até o ano novo
# prevendo taxa de óbitos para o dia 12 até o ano novo
# prevendo taxa de óbitos para o dia 13 até o ano novo
# prevendo taxa de óbitos para o dia 14 até o ano novo
# prevendo taxa de óbitos para o dia 15 até o ano novo
# prevendo taxa de óbitos para o dia 16 até o ano novo
# prevendo taxa de óbitos para o dia 17 até o ano novo
# prevendo taxa de óbitos para o dia 18 até o ano novo
# prevendo taxa de óbitos para o dia 19 até o ano novo
# prevendo taxa de óbitos para o dia 20 até o ano novo
# prevendo taxa de óbitos para o dia 21 até o ano novo
# prevendo taxa de óbitos para o dia 22 até o ano novo
# prevendo taxa de óbitos para o dia 23 até o ano novo
# prevendo taxa de óbitos para o dia 24 até o ano novo
# prevendo taxa de óbitos para o dia 25 até o ano novo
# prevendo taxa de óbitos para o dia 26 até o ano novo
# prevendo taxa de óbitos para o dia 27 até o ano novo
# prevendo taxa de óbitos para o dia 28 até o ano novo
# prevendo taxa de óbitos para o dia 29 até o ano novo
# prevendo taxa de óbitos para o dia 30 até o ano novo
# prevendo taxa de óbitos para o dia 31 até o ano novo
# prevendo taxa de óbitos para o dia 32 até o ano novo
# prevendo taxa de óbitos para o dia 33 até o ano novo
# prevendo taxa de óbitos para o dia 34 até o ano novo
# prevendo taxa de óbitos para o dia 35 até o ano novo
# prevendo taxa de óbitos para o dia 36 até o ano novo
# prevendo taxa de óbitos para o dia 37 até o ano novo
# prevendo taxa de óbitos para o dia 38 até o ano novo
# prevendo taxa de óbitos para o dia 39 até o ano novo
# prevendo taxa de óbitos para o dia 40 até o ano novo
# prevendo taxa de óbitos para o dia 41 até o ano novo
# prevendo taxa de óbitos para o dia 42 até o ano novo
# prevendo taxa de óbitos para o dia 43 até o ano novo
# prevendo taxa de óbitos para o dia 44 até o ano novo
# prevendo taxa de óbitos para o dia 45 até o ano novo
# prevendo taxa de óbitos para o dia 46 até o ano novo
# prevendo taxa de óbitos para o dia 47 até o ano novo
# prevendo taxa de óbitos para o dia 48 até o ano novo
# prevendo taxa de óbitos para o dia 49 até o ano novo
# prevendo taxa de óbitos para o dia 50 até o ano novo
# prevendo taxa de óbitos para o dia 51 até o ano novo
# prevendo taxa de óbitos para o dia 52 até o ano novo
# prevendo taxa de óbitos para o dia 53 até o ano novo
# prevendo taxa de óbitos para o dia 54 até o ano novo
# prevendo taxa de óbitos para o dia 55 até o ano novo
# prevendo taxa de óbitos para o dia 56 até o ano novo
# prevendo taxa de óbitos para o dia 57 até o ano novo
# prevendo taxa de óbitos para o dia 58 até o ano novo
# prevendo taxa de óbitos para o dia 59 até o ano novo
# prevendo taxa de óbitos para o dia 60 até o ano novo
# prevendo taxa de óbitos para o dia 61 até o ano novo
# prevendo taxa de óbitos para o dia 62 até o ano novo
# prevendo taxa de óbitos para o dia 63 até o ano novo
# prevendo taxa de óbitos para o dia 64 até o ano novo
# prevendo taxa de óbitos para o dia 65 até o ano novo
# prevendo taxa de óbitos para o dia 66 até o ano novo
# prevendo taxa de óbitos para o dia 67 até o ano novo
# prevendo taxa de óbitos para o dia 68 até o ano novo
# prevendo taxa de óbitos para o dia 69 até o ano novo
# prevendo taxa de óbitos para o dia 70 até o ano novo
# prevendo taxa de óbitos para o dia 71 até o ano novo
# prevendo taxa de óbitos para o dia 72 até o ano novo
# prevendo taxa de óbitos para o dia 73 até o ano novo
# prevendo taxa de óbitos para o dia 74 até o ano novo
# prevendo taxa de óbitos para o dia 75 até o ano novo
# prevendo taxa de óbitos para o dia 76 até o ano novo
# prevendo taxa de óbitos para o dia 77 até o ano novo
# prevendo taxa de óbitos para o dia 78 até o ano novo
# prevendo taxa de óbitos para o dia 79 até o ano novo
# prevendo taxa de óbitos para o dia 80 até o ano novo
# prevendo taxa de óbitos para o dia 81 até o ano novo
# prevendo taxa de óbitos para o dia 82 até o ano novo
# prevendo taxa de óbitos para o dia 83 até o ano novo
# prevendo taxa de óbitos para o dia 84 até o ano novo
# prevendo taxa de óbitos para o dia 85 até o ano novo
# prevendo taxa de óbitos para o dia 86 até o ano novo
# prevendo taxa de óbitos para o dia 87 até o ano novo
# prevendo taxa de óbitos para o dia 88 até o ano novo
# prevendo taxa de óbitos para o dia 89 até o ano novo
# prevendo taxa de óbitos para o dia 90 até o ano novo
# prevendo taxa de óbitos para o dia 91 até o ano novo
# prevendo taxa de óbitos para o dia 92 até o ano novo
# prevendo taxa de óbitos para o dia 93 até o ano novo
# prevendo taxa de óbitos para o dia 94 até o ano novo
# prevendo taxa de óbitos para o dia 95 até o ano novo
# prevendo taxa de óbitos para o dia 96 até o ano novo
# prevendo taxa de óbitos para o dia 97 até o ano novo
# prevendo taxa de óbitos para o dia 98 até o ano novo
# prevendo taxa de óbitos para o dia 99 até o ano novo
# prevendo taxa de óbitos para o dia 100 até o ano novo
# prevendo taxa de óbitos para o dia 101 até o ano novo
# prevendo taxa de óbitos para o dia 102 até o ano novo
# prevendo taxa de óbitos para o dia 103 até o ano novo
# prevendo taxa de óbitos para o dia 104 até o ano novo
# prevendo taxa de óbitos para o dia 105 até o ano novo
# prevendo taxa de óbitos para o dia 106 até o ano novo
# prevendo taxa de óbitos para o dia 107 até o ano novo
# prevendo taxa de óbitos para o dia 108 até o ano novo
# prevendo taxa de óbitos para o dia 109 até o ano novo
# prevendo taxa de óbitos para o dia 110 até o ano novo
# prevendo taxa de óbitos para o dia 111 até o ano novo
# prevendo taxa de óbitos para o dia 112 até o ano novo
# prevendo taxa de óbitos para o dia 113 até o ano novo
# prevendo taxa de óbitos para o dia 114 até o ano novo
# prevendo taxa de óbitos para o dia 115 até o ano novo
# prevendo taxa de óbitos para o dia 116 até o ano novo
# prevendo taxa de óbitos para o dia 117 até o ano novo
# prevendo taxa de óbitos para o dia 118 até o ano novo
# prevendo taxa de óbitos para o dia 119 até o ano novo
# prevendo taxa de óbitos para o dia 120 até o ano novo
# prevendo taxa de óbitos para o dia 121 até o ano novo
# prevendo taxa de óbitos para o dia 122 até o ano novo
# prevendo taxa de óbitos para o dia 123 até o ano novo
# prevendo taxa de óbitos para o dia 124 até o ano novo
# prevendo taxa de óbitos para o dia 125 até o ano novo
# prevendo taxa de óbitos para o dia 126 até o ano novo
# prevendo taxa de óbitos para o dia 127 até o ano novo
# prevendo taxa de óbitos para o dia 128 até o ano novo
# prevendo taxa de óbitos para o dia 129 até o ano novo
# prevendo taxa de óbitos para o dia 130 até o ano novo
# prevendo taxa de óbitos para o dia 131 até o ano novo
# prevendo taxa de óbitos para o dia 132 até o ano novo
# prevendo taxa de óbitos para o dia 133 até o ano novo
# prevendo taxa de óbitos para o dia 134 até o ano novo
# prevendo taxa de óbitos para o dia 135 até o ano novo
# prevendo taxa de óbitos para o dia 136 até o ano novo
# prevendo taxa de óbitos para o dia 137 até o ano novo
# prevendo taxa de óbitos para o dia 138 até o ano novo
# prevendo taxa de óbitos para o dia 139 até o ano novo
# prevendo taxa de óbitos para o dia 140 até o ano novo
# prevendo taxa de óbitos para o dia 141 até o ano novo
# prevendo taxa de óbitos para o dia 142 até o ano novo
# prevendo taxa de óbitos para o dia 143 até o ano novo
# prevendo taxa de óbitos para o dia 144 até o ano novo
# prevendo taxa de óbitos para o dia 145 até o ano novo
# prevendo taxa de óbitos para o dia 146 até o ano novo
# prevendo taxa de óbitos para o dia 147 até o ano novo
# prevendo taxa de óbitos para o dia 148 até o ano novo
# prevendo taxa de óbitos para o dia 149 até o ano novo
# prevendo taxa de óbitos para o dia 150 até o ano novo
# prevendo taxa de óbitos para o dia 151 até o ano novo
# prevendo taxa de óbitos para o dia 152 até o ano novo
# prevendo taxa de óbitos para o dia 153 até o ano novo
# prevendo taxa de óbitos para o dia 154 até o ano novo
# prevendo taxa de óbitos para o dia 155 até o ano novo
# prevendo taxa de óbitos para o dia 156 até o ano novo
# prevendo taxa de óbitos para o dia 157 até o ano novo
# prevendo taxa de óbitos para o dia 158 até o ano novo
# prevendo taxa de óbitos para o dia 159 até o ano novo
# prevendo taxa de óbitos para o dia 160 até o ano novo
# prevendo taxa de óbitos para o dia 161 até o ano novo
# prevendo taxa de óbitos para o dia 162 até o ano novo
# prevendo taxa de óbitos para o dia 163 até o ano novo
# prevendo taxa de óbitos para o dia 164 até o ano novo
# prevendo taxa de óbitos para o dia 165 até o ano novo
# prevendo taxa de óbitos para o dia 166 até o ano novo
# prevendo taxa de óbitos para o dia 167 até o ano novo
# prevendo taxa de óbitos para o dia 168 até o ano novo
# prevendo taxa de óbitos para o dia 169 até o ano novo
# prevendo taxa de óbitos para o dia 170 até o ano novo
# prevendo taxa de óbitos para o dia 171 até o ano novo
# prevendo taxa de óbitos para o dia 172 até o ano novo
# prevendo taxa de óbitos para o dia 173 até o ano novo
# prevendo taxa de óbitos para o dia 174 até o ano novo
# prevendo taxa de óbitos para o dia 175 até o ano novo
# prevendo taxa de óbitos para o dia 176 até o ano novo
# prevendo taxa de óbitos para o dia 177 até o ano novo
# prevendo taxa de óbitos para o dia 178 até o ano novo
# prevendo taxa de óbitos para o dia 179 até o ano novo
# prevendo taxa de óbitos para o dia 180 até o ano novo
# prevendo taxa de óbitos para o dia 181 até o ano novo
# prevendo taxa de óbitos para o dia 182 até o ano novo
# prevendo taxa de óbitos para o dia 183 até o ano novo
# prevendo taxa de óbitos para o dia 184 até o ano novo
# prevendo taxa de óbitos para o dia 185 até o ano novo
# prevendo taxa de óbitos para o dia 186 até o ano novo
# prevendo taxa de óbitos para o dia 187 até o ano novo
# prevendo taxa de óbitos para o dia 188 até o ano novo
# prevendo taxa de óbitos para o dia 189 até o ano novo
# prevendo taxa de óbitos para o dia 190 até o ano novo
# prevendo taxa de óbitos para o dia 191 até o ano novo
# prevendo taxa de óbitos para o dia 192 até o ano novo
# prevendo taxa de óbitos para o dia 193 até o ano novo
# prevendo taxa de óbitos para o dia 194 até o ano novo
# prevendo taxa de óbitos para o dia 195 até o ano novo
# prevendo taxa de óbitos para o dia 196 até o ano novo
# prevendo taxa de óbitos para o dia 197 até o ano novo
# prevendo taxa de óbitos para o dia 198 até o ano novo
# prevendo taxa de óbitos para o dia 199 até o ano novo
# prevendo taxa de óbitos para o dia 200 até o ano novo
# prevendo taxa de óbitos para o dia 201 até o ano novo
# prevendo taxa de óbitos para o dia 202 até o ano novo
# prevendo taxa de óbitos para o dia 203 até o ano novo
# prevendo taxa de óbitos para o dia 204 até o ano novo
# prevendo taxa de óbitos para o dia 205 até o ano novo
# prevendo taxa de óbitos para o dia 206 até o ano novo
# prevendo taxa de óbitos para o dia 207 até o ano novo
# prevendo taxa de óbitos para o dia 208 até o ano novo
# prevendo taxa de óbitos para o dia 209 até o ano novo
# prevendo taxa de óbitos para o dia 210 até o ano novo
# prevendo taxa de óbitos para o dia 211 até o ano novo
# prevendo taxa de óbitos para o dia 212 até o ano novo
# prevendo taxa de óbitos para o dia 213 até o ano novo
# prevendo taxa de óbitos para o dia 214 até o ano novo
# prevendo taxa de óbitos para o dia 215 até o ano novo
# prevendo taxa de óbitos para o dia 216 até o ano novo
# prevendo taxa de óbitos para o dia 217 até o ano novo
# prevendo taxa de óbitos para o dia 218 até o ano novo
# prevendo taxa de óbitos para o dia 219 até o ano novo
# prevendo taxa de óbitos para o dia 220 até o ano novo
# prevendo taxa de óbitos para o dia 221 até o ano novo
# prevendo taxa de óbitos para o dia 222 até o ano novo
# prevendo taxa de óbitos para o dia 223 até o ano novo
# prevendo taxa de óbitos para o dia 224 até o ano novo
# prevendo taxa de óbitos para o dia 225 até o ano novo
# prevendo taxa de óbitos para o dia 226 até o ano novo
# prevendo taxa de óbitos para o dia 227 até o ano novo
# prevendo taxa de óbitos para o dia 228 até o ano novo
# prevendo taxa de óbitos para o dia 229 até o ano novo
# prevendo taxa de óbitos para o dia 230 até o ano novo
# prevendo taxa de óbitos para o dia 231 até o ano novo
# prevendo taxa de óbitos para o dia 232 até o ano novo
# prevendo taxa de óbitos para o dia 233 até o ano novo
# prevendo taxa de óbitos para o dia 234 até o ano novo
# prevendo taxa de óbitos para o dia 235 até o ano novo
# prevendo taxa de óbitos para o dia 236 até o ano novo
# prevendo taxa de óbitos para o dia 237 até o ano novo
# prevendo taxa de óbitos para o dia 238 até o ano novo
# prevendo taxa de óbitos para o dia 239 até o ano novo
# prevendo taxa de óbitos para o dia 240 até o ano novo
# prevendo taxa de óbitos para o dia 241 até o ano novo
# prevendo taxa de óbitos para o dia 242 até o ano novo
# prevendo taxa de óbitos para o dia 243 até o ano novo
# prevendo taxa de óbitos para o dia 244 até o ano novo
# prevendo taxa de óbitos para o dia 245 até o ano novo
# prevendo taxa de óbitos para o dia 246 até o ano novo
# prevendo taxa de óbitos para o dia 247 até o ano novo
# prevendo taxa de óbitos para o dia 248 até o ano novo
# prevendo taxa de óbitos para o dia 249 até o ano novo
# prevendo taxa de óbitos para o dia 250 até o ano novo
# prevendo taxa de óbitos para o dia 251 até o ano novo
# prevendo taxa de óbitos para o dia 252 até o ano novo
# prevendo taxa de óbitos para o dia 253 até o ano novo
# prevendo taxa de óbitos para o dia 254 até o ano novo
# prevendo taxa de óbitos para o dia 255 até o ano novo
# prevendo taxa de óbitos para o dia 256 até o ano novo
# prevendo taxa de óbitos para o dia 257 até o ano novo
# prevendo taxa de óbitos para o dia 258 até o ano novo
# prevendo taxa de óbitos para o dia 259 até o ano novo
# prevendo taxa de óbitos para o dia 260 até o ano novo
# prevendo taxa de óbitos para o dia 261 até o ano novo
# prevendo taxa de óbitos para o dia 262 até o ano novo
# prevendo taxa de óbitos para o dia 263 até o ano novo
# prevendo taxa de óbitos para o dia 264 até o ano novo
# prevendo taxa de óbitos para o dia 265 até o ano novo
# prevendo taxa de óbitos para o dia 266 até o ano novo
# prevendo taxa de óbitos para o dia 267 até o ano novo
# prevendo taxa de óbitos para o dia 268 até o ano novo
# prevendo taxa de óbitos para o dia 269 até o ano novo
# prevendo taxa de óbitos para o dia 270 até o ano novo
# prevendo taxa de óbitos para o dia 271 até o ano novo
# prevendo taxa de óbitos para o dia 272 até o ano novo
# prevendo taxa de óbitos para o dia 273 até o ano novo
# prevendo taxa de óbitos para o dia 274 até o ano novo
# prevendo taxa de óbitos para o dia 275 até o ano novo
# prevendo taxa de óbitos para o dia 276 até o ano novo
# prevendo taxa de óbitos para o dia 277 até o ano novo
# prevendo taxa de óbitos para o dia 278 até o ano novo
# prevendo taxa de óbitos para o dia 279 até o ano novo
# prevendo taxa de óbitos para o dia 280 até o ano novo
# prevendo taxa de óbitos para o dia 281 até o ano novo
# prevendo taxa de óbitos para o dia 282 até o ano novo
# prevendo taxa de óbitos para o dia 283 até o ano novo
# prevendo taxa de óbitos para o dia 284 até o ano novo
# prevendo taxa de óbitos para o dia 285 até o ano novo
# prevendo taxa de óbitos para o dia 286 até o ano novo
# prevendo taxa de óbitos para o dia 287 até o ano novo
# prevendo taxa de óbitos para o dia 288 até o ano novo
# prevendo taxa de óbitos para o dia 289 até o ano novo
# prevendo taxa de óbitos para o dia 290 até o ano novo
# prevendo taxa de óbitos para o dia 291 até o ano novo
# prevendo taxa de óbitos para o dia 292 até o ano novo
# prevendo taxa de óbitos para o dia 293 até o ano novo
# prevendo taxa de óbitos para o dia 294 até o ano novo
# prevendo taxa de óbitos para o dia 295 até o ano novo
# prevendo taxa de óbitos para o dia 296 até o ano novo
# prevendo taxa de óbitos para o dia 297 até o ano novo
# prevendo taxa de óbitos para o dia 298 até o ano novo
# prevendo taxa de óbitos para o dia 299 até o ano novo
# prevendo taxa de óbitos para o dia 300 até o ano novo
# prevendo taxa de óbitos para o dia 301 até o ano novo
# prevendo taxa de óbitos para o dia 302 até o ano novo
# prevendo taxa de óbitos para o dia 303 até o ano novo
# prevendo taxa de óbitos para o dia 304 até o ano novo
# prevendo taxa de óbitos para o dia 305 até o ano novo
# prevendo taxa de óbitos para o dia 306 até o ano novo
# prevendo taxa de óbitos para o dia 307 até o ano novo
# prevendo taxa de óbitos para o dia 308 até o ano novo
# prevendo taxa de óbitos para o dia 309 até o ano novo
# prevendo taxa de óbitos para o dia 310 até o ano novo
# prevendo taxa de óbitos para o dia 311 até o ano novo
# prevendo taxa de óbitos para o dia 312 até o ano novo
# prevendo taxa de óbitos para o dia 313 até o ano novo
# prevendo taxa de óbitos para o dia 314 até o ano novo
# prevendo taxa de óbitos para o dia 315 até o ano novo
# prevendo taxa de óbitos para o dia 316 até o ano novo
# prevendo taxa de óbitos para o dia 317 até o ano novo
# prevendo taxa de óbitos para o dia 318 até o ano novo
# prevendo taxa de óbitos para o dia 319 até o ano novo
# prevendo taxa de óbitos para o dia 320 até o ano novo
# prevendo taxa de óbitos para o dia 321 até o ano novo
# prevendo taxa de óbitos para o dia 322 até o ano novo
# prevendo taxa de óbitos para o dia 323 até o ano novo
# prevendo taxa de óbitos para o dia 324 até o ano novo
# prevendo taxa de óbitos para o dia 325 até o ano novo
# prevendo taxa de óbitos para o dia 326 até o ano novo
# prevendo taxa de óbitos para o dia 327 até o ano novo
# prevendo taxa de óbitos para o dia 328 até o ano novo
# prevendo taxa de óbitos para o dia 329 até o ano novo
# prevendo taxa de óbitos para o dia 330 até o ano novo
# prevendo taxa de óbitos para o dia 331 até o ano novo
# prevendo taxa de óbitos para o dia 332 até o ano novo
# prevendo taxa de óbitos para o dia 333 até o ano novo
# prevendo taxa de óbitos para o dia 334 até o ano novo
# prevendo taxa de óbitos para o dia 335 até o ano novo
# prevendo taxa de óbitos para o dia 336 até o ano novo
# prevendo taxa de óbitos para o dia 337 até o ano novo
# prevendo taxa de óbitos para o dia 338 até o ano novo
# prevendo taxa de óbitos para o dia 339 até o ano novo
# prevendo taxa de óbitos para o dia 340 até o ano novo
# prevendo taxa de óbitos para o dia 341 até o ano novo
# prevendo taxa de óbitos para o dia 342 até o ano novo
# prevendo taxa de óbitos para o dia 343 até o ano novo
# prevendo taxa de óbitos para o dia 344 até o ano novo
# prevendo taxa de óbitos para o dia 345 até o ano novo
# prevendo taxa de óbitos para o dia 346 até o ano novo
# prevendo taxa de óbitos para o dia 347 até o ano novo
# prevendo taxa de óbitos para o dia 348 até o ano novo
# prevendo taxa de óbitos para o dia 349 até o ano novo
# prevendo taxa de óbitos para o dia 350 até o ano novo
# prevendo taxa de óbitos para o dia 351 até o ano novo
# prevendo taxa de óbitos para o dia 352 até o ano novo
# prevendo taxa de óbitos para o dia 353 até o ano novo
# prevendo taxa de óbitos para o dia 354 até o ano novo
# prevendo taxa de óbitos para o dia 355 até o ano novo
# prevendo taxa de óbitos para o dia 356 até o ano novo
# prevendo taxa de óbitos para o dia 357 até o ano novo
# prevendo taxa de óbitos para o dia 358 até o ano novo
# prevendo taxa de óbitos para o dia 359 até o ano novo
# prevendo taxa de óbitos para o dia 360 até o ano novo
# prevendo taxa de óbitos para o dia 361 até o ano novo
# prevendo taxa de óbitos para o dia 362 até o ano novo
# prevendo taxa de óbitos para o dia 363 até o ano novo
# prevendo taxa de óbitos para o dia 364 até o ano novo

# %%
X = np.array(data_BR.newDeaths)
X = X.astype('float32').reshape(-1,1)

# Prepara o vetor para plotagem dos valores originais
originalX = np.empty([len(X)+len(previsoes_proximo_ano), ]).reshape(-1,1)
originalX[:, :] = np.nan
originalX[0:len(X), :] = X

# Prepara o vetor para plotagem do conjunto das predições
PredictPlot = np.empty_like(originalX)
PredictPlot[:, :] = np.nan
PredictPlot[len(X):len(X)+len(previsoes_proximo_ano), :] = previsoes_proximo_ano

# Plota o dataset, as predições sobre o conjunto de treinamento e teste
plt.figure(figsize=(20,14))
plt.plot(originalX, color = 'b')
plt.plot(PredictPlot, color='r')
plt.show()

# %%
previsoes_proximo_ano
# Out:
# array([[302.3142 ],
#        [267.8532 ],
#        [335.1274 ],
#        [309.6184 ],
#        [277.33228],
#        [232.3173 ],
#        [192.62733],
#        [186.82039],
#        [237.1979 ],
#        [237.05797],
#        [232.75325],
#        [211.88011],
#        [180.06807],
#        [144.3968 ],
#        [163.08127],
#        [186.96054],
#        [192.52382],
#        [188.22598],
#        [181.1005 ],
#        [169.2771 ],
#        [152.37662],
#        [152.44746],
#        [173.68617],
#        [170.20386],
#        [166.99776],
#        [162.97055],
#        [156.76836],
#        [147.59761],
#        [153.02693],
#        [163.80405],
#        [159.85085],
#        [158.4697 ],
#        [156.0855 ],
#        [152.62605],
#        [147.97499],
#        [152.6883 ],
#        [157.34761],
#        [155.61797],
#        [154.63028],
#        [152.8073 ],
#        [150.76155],
#        [148.52818],
#        [151.1693 ],
#        [153.91542],
#        [152.49753],
#        [151.77919],
#        [150.80458],
#        [149.69125],
#        [148.81662],
#        [150.25386],
#        [151.55937],
#        [150.69449],
#        [150.41264],
#        [149.86047],
#        [149.14983],
#        [148.79979],
#        [149.80547],
#        [150.24635],
#        [149.85495],
#        [149.7521 ],
#        [149.44383],
#        [149.03342],
#        [148.9678 ],
#        [149.5077 ],
#        [149.62651],
#        [149.45032],
#        [149.31679],
#        [149.13316],
#        [148.9062 ],
#        [149.00986],
#        [149.31956],
#        [149.2864 ],
#        [149.1959 ],
#        [149.143  ],
#        [149.04527],
#        [148.92241],
#        [149.0311 ],
#        [149.17892],
#        [149.13164],
#        [149.09573],
#        [149.04955],
#        [148.98239],
#        [148.9263 ],
#        [148.99925],
#        [149.07884],
#        [149.0484 ],
#        [149.03036],
#        [149.00551],
#        [148.96902],
#        [148.94398],
#        [148.97923],
#        [149.02304],
#        [148.9974 ],
#        [148.98628],
#        [148.97084],
#        [148.95   ],
#        [148.9411 ],
#        [148.96634],
#        [148.98132],
#        [148.96902],
#        [148.9677 ],
#        [148.95963],
#        [148.9486 ],
#        [148.94357],
#        [148.95934],
#        [148.96454],
#        [148.95946],
#        [148.956  ],
#        [148.95085],
#        [148.94452],
#        [148.94595],
#        [148.95438],
#        [148.95433],
#        [148.9518 ],
#        [148.95041],
#        [148.94783],
#        [148.94453],
#        [148.94658],
#        [148.95088],
#        [148.95006],
#        [148.94885],
#        [148.9479 ],
#        [148.94637],
#        [148.94455],
#        [148.94658],
#        [148.94858],
#        [148.94775],
#        [148.94751],
#        [148.94682],
#        [148.9458 ],
#        [148.94508],
#        [148.946  ],
#        [148.94717],
#        [148.9466 ],
#        [148.94629],
#        [148.94594],
#        [148.94533],
#        [148.94502],
#        [148.94565],
#        [148.94618],
#        [148.94582],
#        [148.94576],
#        [148.94554],
#        [148.94527],
#        [148.94507],
#        [148.9455 ],
#        [148.9457 ],
#        [148.94554],
#        [148.94543],
#        [148.9453 ],
#        [148.94513],
#        [148.94514],
#        [148.94536],
#        [148.94539],
#        [148.94531],
#        [148.94527],
#        [148.9452 ],
#        [148.9451 ],
#        [148.94514],
#        [148.94527],
#        [148.94527],
#        [148.94522],
#        [148.9452 ],
#        [148.94516],
#        [148.9451 ],
#        [148.94516],
#        [148.94522],
#        [148.94519],
#        [148.94519],
#        [148.94518],
#        [148.94513],
#        [148.94511],
#        [148.94514],
#        [148.94518],
#        [148.94516],
#        [148.94514],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94514],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94513],
#        [148.94511],
#        [148.94511],
#        [148.94513],
#        [148.94513],
#        [148.94513]], dtype=float32)
